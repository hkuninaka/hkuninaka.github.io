# %% [markdown]
# # 物理学研究室について
#
# （2020.12.17）
#
# - 「物理学研究室（理論）」とか「統計物理学研究室」という名前もあります。
# - 　２０１９年度までは物理学研究室（実験）（または物性物理学研究室）もありましたが、教員の退職により現在は本研究室だけです。

# %% [markdown]
# ## ３年間の流れ
#
# - 2年次...フレンドシップ子ども科学教室の運営（4〜8月）（**教育実地研究基礎**）
# - 3年次...青少年のための科学の祭典の準備（10月〜11月）（**教育実地研究**）
# - 4年次...就職活動（教員採用試験、公務員試験、民間企業）、卒業研究

# %% [markdown]
# ## 学生生活
#
# - 学生控え室...物性物理実験室（2年生）、物理学第４実験室（3, 4年生）。
# - 物理の必修科目以外に、4年次前期終了までに「物理学講義I〜IV」、「物理学実験」を履修してください（全て履修することが望ましい）。
# - 理科情報基礎（物理）もおすすめです。ICT機器を用いた授業に強くなれるでしょう。
# - 週に一回学年ごとのゼミを行う予定です。

# %% [markdown]
# ## 卒業研究のテーマ
#
# - 私がこれまでに関わってきた研究（弾性論、ソフトマター（粉粒体、液滴）、分子シミュレーション、自然・社会現象に見られる統計法則と確率モデル等）の周辺からテーマを提案するので、その中から選んでもらいます。
# - 研究と教材開発の両方の側面を持ったテーマを選ぶつもりです。
# - 実験装置を自身で設計・作成できるようになってほしいです（３年次の物理学実験から行います）。
# - 必要に応じてR、Python、Wolfram言語などのプログラム言語を学習してもらいます。

# %% [markdown]
# ## これまでの卒業論文・修士論文のテーマ（作成中）

# %% [markdown]
# ### 弾性ロッドの強制振動とカオス
#
# - 弾性ロッドの先端におもりをつけたものを強制振動させたときのおもりの運動と、振動パラメータ（振動数、振幅等）の関係を調べました。
# - 物性物理研究室の卒研生が実験を行い、本研究室の卒研生がシミュレーションを行いました。

# %% [markdown]
# ### アルゴン原子の分子動力学シミュレーション

# %% [markdown]
# ### 野球ボールの反発係数とホームランの出現確率の関係
#
# - 野球ボールの反発係数を変えたときに、打球がホームランになる確率がどれだけ変化するかを調べました。
# - プロ野球の投球データから、球速とコースの確率分布をデータ解析により調べました（Rを使用）。
# - バットとボールの衝突シミュレーションを行い、ホームランの出現確率を定量的に評価しました（Pythonを使用）。

# %% [markdown]
# ### ビリヤード球の衝突
#
# - ビリヤード台の上にカメラを取り付け、球の運動を計測するシステムを作りました。

# %% [markdown]
# ### 蜃気楼の現象を理解するための教材開発
#
# - アクリル容器と寒天を用いて蜃気楼を再現する簡単な実験装置があります。
# - この実験装置を作成し、蜃気楼の原理を解説する教材を考えました。

# %% [markdown]
# ### 虹ビーズを用いた虹の研究
#
# - 虹ビーズを用いて実験室に虹を再現します。
# - その虹の特徴を定量的に調べ、自然界でまれに観察される三次の虹を作り出すことができました。

# %% [markdown]
# ### バットとボールの衝突実験（2018年度〜）
#
# - 高校野球で金属バットを氷で冷やすと打球が遠くまで飛ぶという「説」があります。
# - この研究では金属バットや、今後高校野球で導入が進むと思われる「低反発バット」を用いて、硬式球との衝突実験を行っています。
# - バットの温度と、バットと球の間の反発係数の関係を調べ、その「説」の真偽を確かめています。

# %% [markdown]
# ### 光の性質に関する教材開発
#
# - 空き缶とマッチ棒を用いて火を起こすための集光器を作成し、中学校理科「光の性質」の授業における教材化を行いました。
# - 研究を行った学生によると、サントリー「BLACK BOSS」の空き缶が集光器を作るのに最適なのだそうです。

# %% [markdown]
# ### シミュレーションソフトAlgodooを用いた高校物理の教材開発
#
# - 物理シミュレーションソフト「Algodoo」を用いて、高校物理における「誤概念」を正す教材の開発を行いました。

# %% [markdown]
# ### Youtubeの動画再生回数の分布に見られる統計的な特徴
#
# - Youtubeの動画の統計データを解析し、再生回数の統計分布に見られる特徴を調べました。
# - 日本やアメリカなどの国別の統計分布を調べ、様々な自然・社会現象に見られる「対数正規分布」や「べき分布」が観測されることがわかりました。

# %% [markdown]
# ### チョークの破壊実験（2020年度）
#
# - チョークを床に落とすと必ず３本に割れるという「説」があります。
# - 先行研究（自由研究を含む）では落とす高さによって割れる本数が決まるということがわかっています。
# - この研究では高さを変えてチョークを落下させ、割れる本数や、割れ方の形態を調べています。

# %% [markdown]
# ### 感染症の数理モデルのシミュレーション（2020年度）
#
# - 感染症流行のSIRモデルは、covid-19の感染者数や流行期間の予測にも用いられています。
# - SIRモデルとは、未感染者、感染者、回復者の数の時間変化を表す微分方程式で、コンピューターで数値計算することでそれぞれの時間変化がわかります。
# - この研究ではモデルに含まれるパラメータ（平均接触人数など）を変化させ、感染者の最終的な割合や流行期間の長さなどを調べています。

# %% [markdown]
# ### 微視的な転がり摩擦の分子動力学シミュレーション（修士論文）
#
# - 数百個のアルゴン原子から成るクラスターに外力をかけ、同じくアルゴン粒子から成る基板の上を転がすシミュレーションを行いました（Fortran90を使用）。
# - クラスターと基板の間に働く引力相互作用を変化させたときに、転がりの形態がどう変化するのかを定量的に調べました。

# %% [markdown]
# ### シミュレーション教材PhETを用いた授業マニュアルの作成（修士論文）
#
# - コロラド大学で開発された無料の科学教育シミュレーションPhETを、中学校理科の授業で活用するための教員向けマニュアルを作成しました。

# %% [markdown]
# ### 滴状凝縮に見られる液滴のサイズ分布（修士論文）
#
# - サランラップやガラス面に凝縮する液滴のサイズ分布に見られる統計的性質や、時間発展を実験により調べました。
# - また確率的乗算過程に基づく簡単な液滴成長のシミュレーションを行い、実験データを定性的に再現できることを示しました。
